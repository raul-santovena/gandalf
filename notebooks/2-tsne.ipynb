# %%
import sys

from bokeh.io import output_notebook

# My modules
sys.path.append("../") # To support the use of the tool without packaging
from gandalf.test import tsne_comparison

# %% [markdown]
# ## Arguments

# %%
ROOT_FOLDER="experiments-results/"

ID = "sample"
RANDOM_STATE = 42
EXPORT_GRAPH = False
VERBOSE = 0

# %%
# Needed for the use of bokeh in jupyter notebooks
output_notebook()

# %% [markdown]
# ## T-SNE

# %%
# tsne_comparison(id_=ID, root_folder=ROOT_FOLDER, name="TEST-TSNE", cache='tests/tsne', random_state=RANDOM_STATE,
#                                 export_graph=EXPORT_GRAPH, backend="bokeh", verbose=VERBOSE)

# %%
tsne_comparison(id_=ID, root_folder=ROOT_FOLDER, name="TEST-TSNE", cache='tests/tsne', random_state=RANDOM_STATE,
                                export_graph=EXPORT_GRAPH, backend="matplotlib", verbose=1)
