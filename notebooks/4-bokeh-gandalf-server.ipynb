# %%
import sys

# My modules
sys.path.append("../") # To support the use of the tool without packaging
from gandalf.visualization import bokeh_server

# %%
config_file = 'visualization_config.yaml'

# %%
with open(config_file, 'r') as f:
    print(f.read())

# %%
bokeh_server(config_file)
